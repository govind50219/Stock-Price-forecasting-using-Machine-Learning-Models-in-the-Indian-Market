# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.naive_bayes import GaussianNB
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
os.chdir(r"E:\OneDrive\Desktop\4th sem\HSO201\project")
rel =pd.read_csv('RELIANCE.csv') 
tcs =pd.read_csv('TCS.csv') 
infy =pd.read_csv('INFY.csv') 
hul =pd.read_csv('HINDUNILVR.csv') 
hdfc =pd.read_csv('HDFCBANK.csv')

# %%
rel
# Out:
#            Date         Open         High          Low        Close  \
# 0    2009-05-04   458.404785   479.975311   454.690002   470.614044
# 1    2009-05-11   475.245148   489.212738   456.423553   483.095734
# 2    2009-05-18   531.709900   627.799072   517.841370   541.306458
# 3    2009-05-25   544.835510   571.507690   527.623657   562.641724
# 4    2009-06-01   577.030334   577.030334   534.929382   547.993103
# ..          ...          ...          ...          ...          ...
# 517  2019-04-01  1357.135742  1393.590210  1330.389282  1341.186890
# 518  2019-04-08  1343.267212  1344.753052  1308.595825  1330.488281
# 519  2019-04-15  1332.370483  1376.700317  1322.464355  1372.935913
# 520  2019-04-22  1347.229614  1399.137573  1328.705200  1379.721558
# 521  2019-04-29  1379.721558  1404.189697  1353.965698  1395.620850
#
#        Adj Close     Volume
# 0     426.631439   87644390
# 1     437.946655   83869117
# 2     490.717102  103763496
# 3     510.058472   87655030
# 4     496.778870   73702160
# ..           ...        ...
# 517  1328.811035   41453537
# 518  1318.211182   37850396
# 519  1360.267212   30427878
# 520  1366.990234   48483456
# 521  1382.742798   25650550
#
# [522 rows x 7 columns]

# %%
rel.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   522.000000   522.000000   522.000000   522.000000   522.000000
# mean    571.335366   587.764072   556.241823   572.417658   548.579649
# std     233.453430   240.716594   228.344837   235.989672   241.065992
# min     335.321472   348.100342   333.365021   339.407745   314.306183
# 25%     430.896782   441.737778   417.727860   430.376716   406.962601
# 50%     492.308411   504.170959   481.349777   492.011215   462.664261
# 75%     540.414917   559.063126   527.097397   541.204300   512.350006
# max    1379.721558  1404.189697  1353.965698  1395.620850  1382.742798
#
#              Volume
# count  5.220000e+02
# mean   3.923586e+07
# std    1.727671e+07
# min    1.361037e+07
# 25%    2.717088e+07
# 50%    3.549132e+07
# 75%    4.609215e+07
# max    1.292719e+08

# %%
infy.shape
# Out:
# (522, 7)

# %%
min_max_scaler = preprocessing.MinMaxScaler()

for co in [rel, infy, tcs, hul, hdfc] :
    X = np.zeros([519,1])
    Y = np.zeros([519,1]).astype('int')
    for i in range (0,519):
        X[i,:]=np.mean(co.loc[i:(i+2),'Volume'])
        Y[i,:]=np.array(co.loc[i+3,'Adj Close'])
    X = min_max_scaler.fit_transform(X)
    Y = min_max_scaler.fit_transform(Y)
    plt.plot(X, color = 'red', label = 'volume of 3 weeks')
    plt.plot(Y, color = 'blue', label = 'this week')
    plt.xlabel("Week")
    plt.ylabel("Normalised value")
    plt.legend()
    plt.show()

# %%
for co in [rel, infy, tcs, hul, hdfc] :
    X = np.zeros([519,1])
    Y = np.zeros([519,1]).astype('int')
    for i in range (0,519):
        X[i,:]=np.mean(co.loc[i:(i+2),'Adj Close'])
        Y[i,]=np.array(co.loc[i+3,'Adj Close'])
    plt.plot(X, color = 'red', label = 'past 3 weeks')
    plt.plot(Y, color = 'blue', label = 'this week')
    plt.xlabel("Week")
    plt.ylabel("Adj Close")
    plt.legend()
    plt.show()

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split

X = np.zeros([519,3])  
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(rel.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(rel.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
model = Sequential()
model.add(Dense(32, activation = 'relu', input_dim=3))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam',loss = 'mean_absolute_error')
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
y_pred = model.predict(X_test)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 2ms/step - loss: 546.3342
# Epoch 2/100
# 42/42 [==============================] - 0s 3ms/step - loss: 547.5059
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 541.2367
# Epoch 4/100
# 42/42 [==============================] - 0s 3ms/step - loss: 497.4674
# Epoch 5/100
# 42/42 [==============================] - 0s 3ms/step - loss: 399.3383
# Epoch 6/100
# 42/42 [==============================] - 0s 3ms/step - loss: 231.9469
# Epoch 7/100
# 42/42 [==============================] - 0s 2ms/step - loss: 158.0541
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 123.6555
# Epoch 9/100
# 42/42 [==============================] - 0s 3ms/step - loss: 108.9963
# Epoch 10/100
# 42/42 [==============================] - 0s 3ms/step - loss: 99.5222
# Epoch 11/100
# 42/42 [==============================] - 0s 3ms/step - loss: 82.6913
# Epoch 12/100
# 42/42 [==============================] - 0s 2ms/step - loss: 68.3171
# Epoch 13/100
# 42/42 [==============================] - 0s 3ms/step - loss: 54.9836
# Epoch 14/100
# 42/42 [==============================] - 0s 3ms/step - loss: 45.0108
# Epoch 15/100
# 42/42 [==============================] - 0s 3ms/step - loss: 38.9504
# Epoch 16/100
# 42/42 [==============================] - 0s 3ms/step - loss: 37.2461
# Epoch 17/100
# 42/42 [==============================] - 0s 3ms/step - loss: 33.1483
# Epoch 18/100
# 42/42 [==============================] - 0s 3ms/step - loss: 29.3082
# Epoch 19/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.0448
# Epoch 20/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.6703
# Epoch 21/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.2605
# Epoch 22/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.7542
# Epoch 23/100
# 42/42 [==============================] - 0s 2ms/step - loss: 20.8911
# Epoch 24/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.4696
# Epoch 25/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.0059
# Epoch 26/100
# 42/42 [==============================] - 0s 2ms/step - loss: 18.3269
# Epoch 27/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.1166
# Epoch 28/100
# 42/42 [==============================] - 0s 2ms/step - loss: 19.8099
# Epoch 29/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.9917
# Epoch 30/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.6498
# Epoch 31/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.7668
# Epoch 32/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.4739
# Epoch 33/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.7106
# Epoch 34/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.6212
# Epoch 35/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.0683
# Epoch 36/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.1680
# Epoch 37/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.7931
# Epoch 38/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.6115
# Epoch 39/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.0779
# Epoch 40/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.8735
# Epoch 41/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.9279
# Epoch 42/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.8874
# Epoch 43/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.3878
# Epoch 44/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.4570
# Epoch 45/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.2636
# Epoch 46/100
# 42/42 [==============================] - 0s 2ms/step - loss: 17.2488
# Epoch 47/100
# 42/42 [==============================] - 0s 2ms/step - loss: 17.5539
# Epoch 48/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.7792
# Epoch 49/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.2208
# Epoch 50/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.7450
# Epoch 51/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.5072
# Epoch 52/100
# 42/42 [==============================] - 0s 2ms/step - loss: 18.3591
# Epoch 53/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.8549
# Epoch 54/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.7804
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.7898
# Epoch 56/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.0994
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.6283
# Epoch 58/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.7180
# Epoch 59/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.4859
# Epoch 60/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.5240
# Epoch 61/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.0801
# Epoch 62/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.5304
# Epoch 63/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.3890
# Epoch 64/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.3700
# Epoch 65/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.6065
# Epoch 66/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.2518
# Epoch 67/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.9089
# Epoch 68/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.2938
# Epoch 69/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.3590
# Epoch 70/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.1615
# Epoch 71/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.9335
# Epoch 72/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.3649
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 14.1574
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.2646
# Epoch 75/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.3781
# Epoch 76/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.6284
# Epoch 77/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.1722
# Epoch 78/100
# 42/42 [==============================] - 0s 2ms/step - loss: 17.0209
# Epoch 79/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.5454
# Epoch 80/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.7230
# Epoch 81/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.9044: 0s - loss: 17.
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.6117
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.7649
# Epoch 84/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.4615
# Epoch 85/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.4639
# Epoch 86/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.0567
# Epoch 87/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.9902
# Epoch 88/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.2641
# Epoch 89/100
# 42/42 [==============================] - 0s 2ms/step - loss: 15.4826
# Epoch 90/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.8632
# Epoch 91/100
# 42/42 [==============================] - 0s 3ms/step - loss: 14.8168
# Epoch 92/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.8779
# Epoch 93/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.7846
# Epoch 94/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.8972
# Epoch 95/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.7764
# Epoch 96/100
# 42/42 [==============================] - 0s 2ms/step - loss: 16.0185
# Epoch 97/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.1559
# Epoch 98/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.2783
# Epoch 99/100
# 42/42 [==============================] - 0s 3ms/step - loss: 15.7239
# Epoch 100/100
# 42/42 [==============================] - 0s 2ms/step - loss: 14.6536

# %%
y_pred = y_pred.reshape(104,)

# %%
(y_pred - y_test)
# Out:
# array([-16.79550171,  -9.48461914,  52.47698975, -21.38394165,
#        -14.73968506, -25.40466309,   6.0249939 , -10.49301147,
#          4.35971069,  -6.64697266,  14.76092529,   6.09637451,
#        -20.09707642,  28.08520508, -10.40689087, -22.01272583,
#         -8.7616272 , -29.00939941, -31.47424316,  -9.01702881,
#          6.24588013,  -7.13247681,   5.76690674, -29.10281372,
#          6.2807312 , -11.70220947, -22.75967407,   7.10205078,
#        -13.94445801, -19.92962646, -36.17330933,   0.14682007,
#        -18.54086304,   7.86221313,  26.19421387, -38.7008667 ,
#          7.04510498,  -5.79559326,  -5.48455811, -12.41207886,
#         16.29318237,  24.81658936,  -9.13430786,  14.18847656,
#         -3.06835938, -21.6546936 , -20.02096558,  -7.04452515,
#          4.46896362,  11.87661743,   4.42840576,  34.43551636,
#         15.61294556, -13.98406982,  22.20236206,  -3.53829956,
#        -43.82006836, -21.95230103, -34.8677063 ,  28.73733521,
#         25.55889893,  23.36230469,  44.32080078,  -3.91513062,
#          4.79553223,  -6.78295898,   3.56777954,  -3.62942505,
#        -10.99282837,  -7.82070923,  -3.44772339,  15.51724243,
#        -32.47015381, -15.41134644,  -8.84393311,  29.04962158,
#        -31.62030029,  21.64953613, -12.15548706,  -7.24996948,
#         -8.70602417, -12.78079224, -15.08740234, -11.41830444,
#         16.48254395, -31.81137085,  13.57681274,   0.67410278,
#         17.33465576,  11.49813843, -15.40921021, -22.19049072,
#        -19.52630615,   7.3157959 , -17.15103149, -27.76879883,
#        -28.00601196, -20.27850342, -30.28692627,   2.95211792,
#         -7.25442505,  19.0112915 , -24.93484497,  -7.63095093])

# %%
mae= sum(abs(y_pred - y_test) ) / len(y_test)
rmse = np.sqrt(sum( (y_pred - y_test)**2 ) / len(y_test))
r2 = r2_score(y_test, y_pred)
print ("MAE : ", mae)
print ("RMSE : ", rmse)
print ("R2_score : ", r2)
# Out:
# MAE :  16.28123327401968
# RMSE :  19.499225537441152
# R2_score :  0.9946056503555923

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split

X = np.zeros([519,3])  
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(infy.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(infy.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
model = Sequential()
model.add(Dense(32, activation = 'relu', input_dim=3))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam',loss = 'mean_absolute_error')
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
y_pred = model.predict(X_test)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 2ms/step - loss: 387.7786
# Epoch 2/100
# 42/42 [==============================] - 0s 3ms/step - loss: 370.3365
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 345.7164
# Epoch 4/100
# 42/42 [==============================] - 0s 2ms/step - loss: 248.0174
# Epoch 5/100
# 42/42 [==============================] - 0s 2ms/step - loss: 122.2492
# Epoch 6/100
# 42/42 [==============================] - 0s 2ms/step - loss: 111.3272
# Epoch 7/100
# 42/42 [==============================] - 0s 2ms/step - loss: 98.8845
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 86.5262
# Epoch 9/100
# 42/42 [==============================] - 0s 3ms/step - loss: 66.0206
# Epoch 10/100
# 42/42 [==============================] - 0s 2ms/step - loss: 50.3842
# Epoch 11/100
# 42/42 [==============================] - 0s 3ms/step - loss: 32.6627
# Epoch 12/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.6751
# Epoch 13/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.0859
# Epoch 14/100
# 42/42 [==============================] - 0s 3ms/step - loss: 13.3182
# Epoch 15/100
# 42/42 [==============================] - 0s 3ms/step - loss: 13.4947
# Epoch 16/100
# 42/42 [==============================] - 0s 3ms/step - loss: 12.3476
# Epoch 17/100
# 42/42 [==============================] - 0s 3ms/step - loss: 12.1136
# Epoch 18/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.6812
# Epoch 19/100
# 42/42 [==============================] - 0s 2ms/step - loss: 11.9849
# Epoch 20/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.6109
# Epoch 21/100
# 42/42 [==============================] - 0s 2ms/step - loss: 11.7605
# Epoch 22/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.2385
# Epoch 23/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4383
# Epoch 24/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2368
# Epoch 25/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.1675
# Epoch 26/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2165
# Epoch 27/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.6639
# Epoch 28/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.5167
# Epoch 29/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.9256
# Epoch 30/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.5742
# Epoch 31/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2804
# Epoch 32/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.9734
# Epoch 33/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.2760
# Epoch 34/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.2917
# Epoch 35/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.9999
# Epoch 36/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.3718
# Epoch 37/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0089
# Epoch 38/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.3156
# Epoch 39/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0061
# Epoch 40/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.2017
# Epoch 41/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.3569
# Epoch 42/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.5594
# Epoch 43/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.6253
# Epoch 44/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8607
# Epoch 45/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4465
# Epoch 46/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.2250
# Epoch 47/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5779
# Epoch 48/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.4428
# Epoch 49/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.3645
# Epoch 50/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4880
# Epoch 51/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.8657
# Epoch 52/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.7630
# Epoch 53/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.4288
# Epoch 54/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.7366
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.9784
# Epoch 56/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.1472
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.9041
# Epoch 58/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0232
# Epoch 59/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.3688
# Epoch 60/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.4821
# Epoch 61/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.9469
# Epoch 62/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.4850
# Epoch 63/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8811
# Epoch 64/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.4028
# Epoch 65/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5944
# Epoch 66/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.0401
# Epoch 67/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5110
# Epoch 68/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.1767
# Epoch 69/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.6062
# Epoch 70/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8161
# Epoch 71/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4324
# Epoch 72/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8920
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.8709
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.1092
# Epoch 75/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5473
# Epoch 76/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5109
# Epoch 77/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.9746A: 0s - loss: 9.9807
# Epoch 78/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.9407
# Epoch 79/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7995
# Epoch 80/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.9002
# Epoch 81/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.1575
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.7845
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2631
# Epoch 84/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.6207
# Epoch 85/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0933
# Epoch 86/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2678
# Epoch 87/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0533
# Epoch 88/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7594
# Epoch 89/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4787
# Epoch 90/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0953
# Epoch 91/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.9021
# Epoch 92/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.8924
# Epoch 93/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.3330
# Epoch 94/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.6720
# Epoch 95/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.2017
# Epoch 96/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.5604
# Epoch 97/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.0627
# Epoch 98/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.1269
# Epoch 99/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.3643
# Epoch 100/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8880

# %%
y_pred = y_pred.reshape(104,)
mae= sum(abs(y_pred - y_test) ) / len(y_test)
rmse = np.sqrt(sum( (y_pred - y_test)**2 ) / len(y_test))
r2 = r2_score(y_test, y_pred)
print ("MAE : ", mae)
print ("RMSE : ", rmse)
print ("R2_score : ", r2)
# Out:
# MAE :  10.181630501380333
# RMSE :  13.01525453491421
# R2_score :  0.991842279830519

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split

X = np.zeros([519,3])  
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(hdfc.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(hdfc.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
model = Sequential()
model.add(Dense(32, activation = 'relu', input_dim=3))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam',loss = 'mean_absolute_error')
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
y_pred = model.predict(X_test)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 3ms/step - loss: 479.5515
# Epoch 2/100
# 42/42 [==============================] - 0s 2ms/step - loss: 473.9828
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 448.3814
# Epoch 4/100
# 42/42 [==============================] - 0s 3ms/step - loss: 422.4840
# Epoch 5/100
# 42/42 [==============================] - 0s 2ms/step - loss: 246.9639
# Epoch 6/100
# 42/42 [==============================] - 0s 3ms/step - loss: 135.1834
# Epoch 7/100
# 42/42 [==============================] - 0s 3ms/step - loss: 120.7567
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 111.0262
# Epoch 9/100
# 42/42 [==============================] - 0s 3ms/step - loss: 99.8776
# Epoch 10/100
# 42/42 [==============================] - 0s 3ms/step - loss: 78.9832
# Epoch 11/100
# 42/42 [==============================] - 0s 3ms/step - loss: 59.6457
# Epoch 12/100
# 42/42 [==============================] - 0s 3ms/step - loss: 39.8973
# Epoch 13/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.2698
# Epoch 14/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.9752
# Epoch 15/100
# 42/42 [==============================] - 0s 3ms/step - loss: 14.5322
# Epoch 16/100
# 42/42 [==============================] - 0s 3ms/step - loss: 12.8713
# Epoch 17/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.1368
# Epoch 18/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.3497
# Epoch 19/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.8817
# Epoch 20/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.3987
# Epoch 21/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.1497
# Epoch 22/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.1221
# Epoch 23/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.9542
# Epoch 24/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.5022
# Epoch 25/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.3521
# Epoch 26/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.8827
# Epoch 27/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4686
# Epoch 28/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.9387
# Epoch 29/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0985
# Epoch 30/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.1081
# Epoch 31/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2241
# Epoch 32/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.5630
# Epoch 33/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.8334
# Epoch 34/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.8024
# Epoch 35/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.6050
# Epoch 36/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7603
# Epoch 37/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.8793
# Epoch 38/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.6476
# Epoch 39/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.5890
# Epoch 40/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.4360
# Epoch 41/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.5608
# Epoch 42/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8227
# Epoch 43/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0512
# Epoch 44/100
# 42/42 [==============================] - 0s 3ms/step - loss: 11.3036
# Epoch 45/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4658
# Epoch 46/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7584
# Epoch 47/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.8999
# Epoch 48/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2478
# Epoch 49/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8590
# Epoch 50/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8737
# Epoch 51/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.3679
# Epoch 52/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.9452
# Epoch 53/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7829
# Epoch 54/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.5692
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5508
# Epoch 56/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.4436
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.8139
# Epoch 58/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.2319
# Epoch 59/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.1840
# Epoch 60/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.1030
# Epoch 61/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5574
# Epoch 62/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.3102
# Epoch 63/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.0161
# Epoch 64/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.2538
# Epoch 65/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.3683
# Epoch 66/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8245
# Epoch 67/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.2381
# Epoch 68/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.4797
# Epoch 69/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8692
# Epoch 70/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7147
# Epoch 71/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.2108
# Epoch 72/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.9004
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.2610
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.3527
# Epoch 75/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5953
# Epoch 76/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.3071
# Epoch 77/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.7649
# Epoch 78/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8008
# Epoch 79/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.4454
# Epoch 80/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7859
# Epoch 81/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.1979
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.1635
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.8336
# Epoch 84/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.6382
# Epoch 85/100
# 42/42 [==============================] - 0s 3ms/step - loss: 10.3377
# Epoch 86/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.0412
# Epoch 87/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5164
# Epoch 88/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.0575
# Epoch 89/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.5862
# Epoch 90/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.8431
# Epoch 91/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.1101
# Epoch 92/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.7827
# Epoch 93/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.2533
# Epoch 94/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.0119
# Epoch 95/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.7264
# Epoch 96/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.9850
# Epoch 97/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.3012
# Epoch 98/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.1381
# Epoch 99/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.3777
# Epoch 100/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.5931

# %%
y_pred = y_pred.reshape(104,)
mae= sum(abs(y_pred - y_test) ) / len(y_test)
rmse = np.sqrt(sum( (y_pred - y_test)**2 ) / len(y_test))
r2 = r2_score(y_test, y_pred)
print ("MAE : ", mae)
print ("RMSE : ", rmse)
print ("R2_score : ", r2)
# Out:
# MAE :  9.30754778935359
# RMSE :  12.98853820310079
# R2_score :  0.9981265199518946

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split

X = np.zeros([519,3])  
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(hul.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(hul.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
model = Sequential()
model.add(Dense(32, activation = 'relu', input_dim=3))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam',loss = 'mean_absolute_error')
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
y_pred = model.predict(X_test)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 3ms/step - loss: 689.8389
# Epoch 2/100
# 42/42 [==============================] - 0s 3ms/step - loss: 670.3477
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 687.3234
# Epoch 4/100
# 42/42 [==============================] - 0s 3ms/step - loss: 611.3953
# Epoch 5/100
# 42/42 [==============================] - 0s 3ms/step - loss: 479.2370
# Epoch 6/100
# 42/42 [==============================] - 0s 3ms/step - loss: 338.4534
# Epoch 7/100
# 42/42 [==============================] - 0s 3ms/step - loss: 219.1677
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 197.8741
# Epoch 9/100
# 42/42 [==============================] - 0s 2ms/step - loss: 165.1926
# Epoch 10/100
# 42/42 [==============================] - 0s 3ms/step - loss: 130.3790
# Epoch 11/100
# 42/42 [==============================] - 0s 3ms/step - loss: 104.4889
# Epoch 12/100
# 42/42 [==============================] - 0s 3ms/step - loss: 73.2949
# Epoch 13/100
# 42/42 [==============================] - 0s 3ms/step - loss: 56.9244
# Epoch 14/100
# 42/42 [==============================] - 0s 3ms/step - loss: 41.2445
# Epoch 15/100
# 42/42 [==============================] - 0s 3ms/step - loss: 37.8698
# Epoch 16/100
# 42/42 [==============================] - 0s 3ms/step - loss: 32.6955
# Epoch 17/100
# 42/42 [==============================] - 0s 3ms/step - loss: 29.4537
# Epoch 18/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.7471
# Epoch 19/100
# 42/42 [==============================] - 0s 2ms/step - loss: 25.6851
# Epoch 20/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.3413
# Epoch 21/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.3758
# Epoch 22/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.0251
# Epoch 23/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.2484
# Epoch 24/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.1445
# Epoch 25/100
# 42/42 [==============================] - 0s 3ms/step - loss: 21.1639
# Epoch 26/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.7220
# Epoch 27/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.6903
# Epoch 28/100
# 42/42 [==============================] - 0s 2ms/step - loss: 19.8404
# Epoch 29/100
# 42/42 [==============================] - 0s 3ms/step - loss: 21.2969
# Epoch 30/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.5221
# Epoch 31/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.3282
# Epoch 32/100
# 42/42 [==============================] - 0s 2ms/step - loss: 19.2153
# Epoch 33/100
# 42/42 [==============================] - 0s 2ms/step - loss: 20.0293
# Epoch 34/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.2657
# Epoch 35/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.0238
# Epoch 36/100
# 42/42 [==============================] - 0s 3ms/step - loss: 21.0068
# Epoch 37/100
# 42/42 [==============================] - 0s 2ms/step - loss: 19.6242
# Epoch 38/100
# 42/42 [==============================] - 0s 3ms/step - loss: 21.5036
# Epoch 39/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.2094
# Epoch 40/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.7207
# Epoch 41/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.5699
# Epoch 42/100
# 42/42 [==============================] - 0s 2ms/step - loss: 21.4937
# Epoch 43/100
# 42/42 [==============================] - 0s 2ms/step - loss: 20.4311
# Epoch 44/100
# 42/42 [==============================] - 0s 2ms/step - loss: 19.2882
# Epoch 45/100
# 42/42 [==============================] - 0s 2ms/step - loss: 21.7169
# Epoch 46/100
# 42/42 [==============================] - 0s 2ms/step - loss: 20.3088
# Epoch 47/100
# 42/42 [==============================] - 0s 2ms/step - loss: 21.9649
# Epoch 48/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.4289
# Epoch 49/100
# 42/42 [==============================] - 0s 3ms/step - loss: 21.8452
# Epoch 50/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.0283
# Epoch 51/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.2929
# Epoch 52/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.4573
# Epoch 53/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.6776
# Epoch 54/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.9709
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.7112
# Epoch 56/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.2301
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.4505
# Epoch 58/100
# 42/42 [==============================] - 0s 2ms/step - loss: 19.3584
# Epoch 59/100
# 42/42 [==============================] - 0s 2ms/step - loss: 18.6938
# Epoch 60/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.3660
# Epoch 61/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.2574
# Epoch 62/100
# 42/42 [==============================] - 0s 2ms/step - loss: 20.9193
# Epoch 63/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.8400
# Epoch 64/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.6977
# Epoch 65/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.2955
# Epoch 66/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.4271
# Epoch 67/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.9462
# Epoch 68/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.8268
# Epoch 69/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.6326
# Epoch 70/100
# 42/42 [==============================] - 0s 2ms/step - loss: 19.5500
# Epoch 71/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.7407
# Epoch 72/100
# 42/42 [==============================] - 0s 2ms/step - loss: 18.8452
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.7021
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.6672
# Epoch 75/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.7660
# Epoch 76/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.9690
# Epoch 77/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.0234
# Epoch 78/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.4372
# Epoch 79/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.6758
# Epoch 80/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.5163
# Epoch 81/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.1821
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.3627
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.7617
# Epoch 84/100
# 42/42 [==============================] - 0s 2ms/step - loss: 18.9957
# Epoch 85/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.7542
# Epoch 86/100
# 42/42 [==============================] - 0s 3ms/step - loss: 20.4210
# Epoch 87/100
# 42/42 [==============================] - 0s 3ms/step - loss: 17.3689
# Epoch 88/100
# 42/42 [==============================] - 0s 2ms/step - loss: 18.7251
# Epoch 89/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.2973
# Epoch 90/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.9390
# Epoch 91/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.4913
# Epoch 92/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.9309
# Epoch 93/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.0826
# Epoch 94/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.3254
# Epoch 95/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.1883
# Epoch 96/100
# 42/42 [==============================] - 0s 2ms/step - loss: 18.5576
# Epoch 97/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.9019
# Epoch 98/100
# 42/42 [==============================] - 0s 3ms/step - loss: 18.5899
# Epoch 99/100
# 42/42 [==============================] - 0s 3ms/step - loss: 16.3889
# Epoch 100/100
# 42/42 [==============================] - 0s 3ms/step - loss: 19.8163

# %%
y_pred = y_pred.reshape(104,)
mae= sum(abs(y_pred - y_test) ) / len(y_test)
rmse = np.sqrt(sum( (y_pred - y_test)**2 ) / len(y_test))
r2 = r2_score(y_test, y_pred)
print ("MAE : ", mae)
print ("RMSE : ", rmse)
print ("R2_score : ", r2)
# Out:
# MAE :  15.656288587130033
# RMSE :  21.952518770664724
# R2_score :  0.9977248426874024

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split

X = np.zeros([519,3])  
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(tcs.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(tcs.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
model = Sequential()
model.add(Dense(32, activation = 'relu', input_dim=3))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam',loss = 'mean_absolute_error')
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
y_pred = model.predict(X_test)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 3ms/step - loss: 928.3167
# Epoch 2/100
# 42/42 [==============================] - 0s 3ms/step - loss: 911.7149
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 908.6957
# Epoch 4/100
# 42/42 [==============================] - 0s 3ms/step - loss: 821.6409
# Epoch 5/100
# 42/42 [==============================] - 0s 3ms/step - loss: 670.2900
# Epoch 6/100
# 42/42 [==============================] - 0s 3ms/step - loss: 518.4144
# Epoch 7/100
# 42/42 [==============================] - 0s 3ms/step - loss: 314.6118
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 250.0320
# Epoch 9/100
# 42/42 [==============================] - 0s 3ms/step - loss: 213.0472
# Epoch 10/100
# 42/42 [==============================] - 0s 2ms/step - loss: 183.8977
# Epoch 11/100
# 42/42 [==============================] - 0s 3ms/step - loss: 147.1351
# Epoch 12/100
# 42/42 [==============================] - 0s 3ms/step - loss: 143.6281
# Epoch 13/100
# 42/42 [==============================] - 0s 3ms/step - loss: 108.7029
# Epoch 14/100
# 42/42 [==============================] - 0s 2ms/step - loss: 92.2334
# Epoch 15/100
# 42/42 [==============================] - 0s 3ms/step - loss: 74.1458
# Epoch 16/100
# 42/42 [==============================] - 0s 3ms/step - loss: 59.6330
# Epoch 17/100
# 42/42 [==============================] - 0s 3ms/step - loss: 49.3853
# Epoch 18/100
# 42/42 [==============================] - 0s 3ms/step - loss: 46.5999
# Epoch 19/100
# 42/42 [==============================] - 0s 2ms/step - loss: 42.8923
# Epoch 20/100
# 42/42 [==============================] - 0s 3ms/step - loss: 38.3911
# Epoch 21/100
# 42/42 [==============================] - 0s 3ms/step - loss: 36.1881
# Epoch 22/100
# 42/42 [==============================] - 0s 2ms/step - loss: 36.9698
# Epoch 23/100
# 42/42 [==============================] - 0s 3ms/step - loss: 32.9609
# Epoch 24/100
# 42/42 [==============================] - 0s 3ms/step - loss: 33.5962
# Epoch 25/100
# 42/42 [==============================] - 0s 3ms/step - loss: 33.2830
# Epoch 26/100
# 42/42 [==============================] - 0s 3ms/step - loss: 30.7902
# Epoch 27/100
# 42/42 [==============================] - 0s 3ms/step - loss: 30.6502
# Epoch 28/100
# 42/42 [==============================] - 0s 3ms/step - loss: 29.1997
# Epoch 29/100
# 42/42 [==============================] - 0s 3ms/step - loss: 28.4959
# Epoch 30/100
# 42/42 [==============================] - 0s 2ms/step - loss: 29.8724
# Epoch 31/100
# 42/42 [==============================] - 0s 3ms/step - loss: 27.4873
# Epoch 32/100
# 42/42 [==============================] - 0s 2ms/step - loss: 25.6064
# Epoch 33/100
# 42/42 [==============================] - 0s 3ms/step - loss: 27.8479
# Epoch 34/100
# 42/42 [==============================] - 0s 3ms/step - loss: 27.2488
# Epoch 35/100
# 42/42 [==============================] - 0s 2ms/step - loss: 26.4593
# Epoch 36/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.3876
# Epoch 37/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.9929
# Epoch 38/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.7022
# Epoch 39/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.6090
# Epoch 40/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.7435
# Epoch 41/100
# 42/42 [==============================] - 0s 3ms/step - loss: 29.6913
# Epoch 42/100
# 42/42 [==============================] - 0s 2ms/step - loss: 24.6985
# Epoch 43/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.3440
# Epoch 44/100
# 42/42 [==============================] - 0s 2ms/step - loss: 26.0549
# Epoch 45/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.8923
# Epoch 46/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.8226
# Epoch 47/100
# 42/42 [==============================] - 0s 2ms/step - loss: 25.7747
# Epoch 48/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.1270
# Epoch 49/100
# 42/42 [==============================] - 0s 2ms/step - loss: 25.9015
# Epoch 50/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.2143
# Epoch 51/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.2649
# Epoch 52/100
# 42/42 [==============================] - 0s 3ms/step - loss: 27.0824
# Epoch 53/100
# 42/42 [==============================] - 0s 2ms/step - loss: 26.3064
# Epoch 54/100
# 42/42 [==============================] - 0s 2ms/step - loss: 24.9755
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.5355
# Epoch 56/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.0336
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.8203
# Epoch 58/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.8283
# Epoch 59/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.3850
# Epoch 60/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.0280
# Epoch 61/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.9316
# Epoch 62/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.1536
# Epoch 63/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.7133
# Epoch 64/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.4932
# Epoch 65/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.8260
# Epoch 66/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.8400
# Epoch 67/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.1669
# Epoch 68/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.9579
# Epoch 69/100
# 42/42 [==============================] - 0s 2ms/step - loss: 26.1043
# Epoch 70/100
# 42/42 [==============================] - 0s 2ms/step - loss: 24.0145
# Epoch 71/100
# 42/42 [==============================] - 0s 2ms/step - loss: 24.7217
# Epoch 72/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.5070
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.0261
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.6350
# Epoch 75/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.2250
# Epoch 76/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.9390
# Epoch 77/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.8489
# Epoch 78/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.1626
# Epoch 79/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.8477
# Epoch 80/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.6260
# Epoch 81/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.9987
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.1730
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.6304
# Epoch 84/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.5235
# Epoch 85/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.2547
# Epoch 86/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.9435
# Epoch 87/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.5247
# Epoch 88/100
# 42/42 [==============================] - 0s 3ms/step - loss: 25.1942
# Epoch 89/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.5404
# Epoch 90/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.7021
# Epoch 91/100
# 42/42 [==============================] - 0s 3ms/step - loss: 21.4384
# Epoch 92/100
# 42/42 [==============================] - 0s 3ms/step - loss: 26.8439
# Epoch 93/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.6390
# Epoch 94/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.3995
# Epoch 95/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.5524
# Epoch 96/100
# 42/42 [==============================] - 0s 3ms/step - loss: 24.1270
# Epoch 97/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.2619
# Epoch 98/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.2697
# Epoch 99/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.6757
# Epoch 100/100
# 42/42 [==============================] - 0s 3ms/step - loss: 22.7819

# %%
y_pred = y_pred.reshape(104,)
mae= sum(abs(y_pred - y_test) ) / len(y_test)
rmse = np.sqrt(sum( (y_pred - y_test)**2 ) / len(y_test))
r2 = r2_score(y_test, y_pred)
print ("MAE : ", mae)
print ("RMSE : ", rmse)
print ("R2_score : ", r2)
# Out:
# MAE :  25.251205004178562
# RMSE :  37.084438480523616
# R2_score :  0.9946566756161187

# %%
def pipeline (co):
   
    X = np.zeros([519,3])
    Y = np.zeros([519,]).astype('int')
    
    for i in range (0,519):
        X[i,:]=np.array(co.loc[i:(i+2),'Adj Close'])
        Y[i,]=np.array(co.loc[i+3,'Adj Close'])
   
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)  
    regressor = [ RandomForestRegressor(), SVR(),  XGBRegressor() , GaussianNB()] 
    for reg in regressor:
        reg.fit(X_train, y_train)
        pred = reg.predict(X_test)
        mae= sum(abs(pred - y_test) ) / len(y_test)
        rmse= np.sqrt(sum( (pred - y_test)**2 ) / len(y_test))
        r2 = r2_score(y_test, pred)
        print ("Regressor : ", reg)
        print ("MAE : ", mae)
        print ("RMSE : ", rmse)
        print ("R2_score : ", r2)

# %%
for co in [rel, infy, tcs, hul, hdfc] :
    pipeline(co)
# Out:
# Regressor :  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# MAE :  17.175961538461543
# RMSE :  22.61523588713523
# R2_score :  0.9927438439931648
# Regressor :  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# MAE :  118.48766793561747
# RMSE :  238.38356205000287
# R2_score :  0.1937736700619781
# Regressor :  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)
# MAE :  19.840182377741886
# RMSE :  25.78522746804084
# R2_score :  0.9905670767390355
# Regressor :  GaussianNB(priors=None, var_smoothing=1e-09)
# MAE :  39.625
# RMSE :  81.26706921294466
# R2_score :  0.9063013005105925
# Regressor :  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# MAE :  11.172980769230772
# RMSE :  14.8500772790012
# R2_score :  0.989380088454138
# Regressor :  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# MAE :  53.02205878105532
# RMSE :  92.76478101559603
# R2_score :  0.5855904839894315
# Regressor :  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)
# MAE :  12.430803445669321
# RMSE :  16.134910368934648
# R2_score :  0.9874629145343611
# Regressor :  GaussianNB(priors=None, var_smoothing=1e-09)
# MAE :  16.240384615384617
# RMSE :  21.980979540012804
# R2_score :  0.9767320803120741
# Regressor :  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# MAE :  24.98442307692305
# RMSE :  34.649290979536865
# R2_score :  0.9953353739892097
# Regressor :  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# MAE :  320.5784309065376
# RMSE :  421.8466405392445
# R2_score :  0.30858735960332895
# Regressor :  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)
# MAE :  30.55002784729004
# RMSE :  43.336895275521755
# R2_score :  0.992703010616217
# Regressor :  GaussianNB(priors=None, var_smoothing=1e-09)
# MAE :  87.1826923076923
# RMSE :  186.33909846133906
# R2_score :  0.8650924966143558
# Regressor :  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# MAE :  15.38509615384616
# RMSE :  21.071135812363725
# R2_score :  0.9979038680918795
# Regressor :  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# MAE :  267.6152645760472
# RMSE :  391.1529275633508
# R2_score :  0.27766961079662666
# Regressor :  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)
# MAE :  18.80832730806791
# RMSE :  25.953629276762637
# R2_score :  0.9968199136691226
# Regressor :  GaussianNB(priors=None, var_smoothing=1e-09)
# MAE :  40.72115384615385
# RMSE :  97.10724642215074
# R2_score :  0.9554809390371813
# Regressor :  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# MAE :  10.242596153846154
# RMSE :  13.838000182051653
# R2_score :  0.9978734520284357
# Regressor :  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# MAE :  143.18920816027403
# RMSE :  223.1287981172984
# R2_score :  0.4471086792980815
# Regressor :  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)
# MAE :  12.176377223088192
# RMSE :  16.715434113251327
# R2_score :  0.996897128143556
# Regressor :  GaussianNB(priors=None, var_smoothing=1e-09)
# MAE :  19.01923076923077
# RMSE :  33.87931068229831
# R2_score :  0.9872533033296514

# %%
X = np.zeros([519,3])
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(rel.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(rel.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
reg = SVR(kernel='linear')
reg.fit(X_train, y_train)
pred = reg.predict(X_test)
r2 = r2_score(y_test, pred)
print ("R2_score : ", r2)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# R2_score :  0.994468298259823

# %%
X = np.zeros([519,3])
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(infy.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(infy.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
reg = SVR(kernel='linear')
reg.fit(X_train, y_train)
pred = reg.predict(X_test)
r2 = r2_score(y_test, pred)
print ("R2_score : ", r2)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# R2_score :  0.9924755778666846

# %%
X = np.zeros([519,3])
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(tcs.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(tcs.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
reg = SVR(kernel='linear')
reg.fit(X_train, y_train)
pred = reg.predict(X_test)
r2 = r2_score(y_test, pred)
print ("R2_score : ", r2)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# R2_score :  0.9950299648228957

# %%
X = np.zeros([519,3])
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(hul.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(hul.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
reg = SVR(kernel='linear')
reg.fit(X_train, y_train)
pred = reg.predict(X_test)
r2 = r2_score(y_test, pred)
print ("R2_score : ", r2)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# R2_score :  0.9982408601831962

# %%
X = np.zeros([519,3])
Y = np.zeros([519,]).astype('int')
for i in range (0,519):
    X[i,:]=np.array(hdfc.loc[i:(i+2),'Adj Close'])
    Y[i,]=np.array(hdfc.loc[i+3,'Adj Close'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
reg = SVR(kernel='linear')
reg.fit(X_train, y_train)
pred = reg.predict(X_test)
r2 = r2_score(y_test, pred)
print ("R2_score : ", r2)
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# R2_score :  0.9984257988542586
